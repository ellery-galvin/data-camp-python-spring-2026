# %% [markdown]
# # Welcome to Intro to Python: Data Camp Spring 2026!
#
# Run the cell below to verify your environment is set up correctly.
# Click on the cell and press **Shift + Enter** to run it.

# %%
import sys
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

print(f"Python version:      {sys.version}")
print(f"pandas version:      {pd.__version__}")
print(f"numpy version:       {np.__version__}")
print(f"matplotlib version:  {matplotlib.__version__}")
print(f"seaborn version:     {sns.__version__}")
print()
print("All packages imported successfully!")

# Quick plot to verify graphics work
sns.set_theme()
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.title("If you can see this plot, everything is working!")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.show()
